# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
ls
# Out:
# Dockerfile                   pipeline.py
# main.sh                      upload-data.ipynb
# ny_taxi_postgres_data/       yellow_tripdata_2021-01.csv

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=200)
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine('postgresql://root:root@locahost:5433/ny_taxi')

# %%
# Out:
# Channels:
#  - defaults
#  - anaconda
#  - conda-forge
# Platform: osx-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /usr/local/Caskroom/miniconda/base/envs/x86_env
#
#   added / updated specs:
#     - anaconda::psycopg2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     psycopg2-2.9.9             |  py311h46256e1_1         174 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         174 KB
#
# The following NEW packages will be INSTALLED:
#
#   psycopg2           anaconda/osx-64::psycopg2-2.9.9-py311h46256e1_1
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
